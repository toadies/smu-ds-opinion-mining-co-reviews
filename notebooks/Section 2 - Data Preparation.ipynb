# %% [markdown]
# # Data Preperation
#
# 1. [Read all the files](#Read-all-the-files)
# 2. [Concat into a single pandas object](#Concat-into-a-single-pandas-object)
#     * Remove duplicates
#     * Drop NAs for job title
# 3. [Clean Job Titles](#Clean-Job-Titles)
# 4. [Save as a pickle](#Save-as-a-pickle)
# 5. [Example how to use pickle](#Example-how-to-use-pickle)

# %% [markdown]
# ## Read all the files

# %%
import os

reviews_path = "../data/Database/"

files = [ reviews_path + i for i in os.listdir(reviews_path) if i.endswith("csv")]
display(files)
# Out:
# ['../data/Database/construction.csv',
#  '../data/Database/computer_software.csv',
#  '../data/Database/automotive.csv',
#  '../data/Database/higher_ed.csv',
#  '../data/Database/retail.csv',
#  '../data/Database/accounting.csv',
#  '../data/Database/IT_services.csv',
#  '../data/Database/financial.csv',
#  '../data/Database/education_management.csv',
#  '../data/Database/hospital_care.csv']

# %% [markdown]
# ## Concat into a single pandas object

# %%
import pandas as pd

li = []

#Loading in first 2 files
for f in files:
    data = pd.read_csv(f)
    data["industry"] = f.split("/")[3][:-4]
    li.append(data)
    
reviews = pd.concat(li, axis=0, ignore_index=True)

reviews.drop(columns=["Unnamed: 0"], inplace=True)

reviews.drop_duplicates(inplace=True)

reviews["job_title"].dropna(inplace=True)

print(reviews.shape)
display( reviews.head() )
# Out:
# (2350814, 13)
#   company_name                              review_title  \
# 0  Fluor Corp.                         fun place to work
# 1  Fluor Corp.                              Im satisfied
# 2  Fluor Corp.  New and intellectually stimulating work.
# 3  Fluor Corp.         For me.... GREAT group of people!
# 4  Fluor Corp.       Good place to work in a Combat Zone
#
#                                   job_title   employee_status  \
# 0  Principal Process Engineering Technician   Former Employee
# 1                     Journeyman Pipefitter   Former Employee
# 2        Systems Engineer and IT Specialist  Current Employee
# 3       General Foreman - Crane and Rigging   Former Employee
# 4                       Security Specialist   Former Employee
#
#             location        date  \
# 0     Sugar Land, TX  2020-02-03
# 1  Crystal River, FL  2020-04-05
# 2    Aliso Viejo, CA  2020-04-05
# 3      Deer Park, TX  2020-04-04
# 4        Afghanistan  2020-04-04
#
#                                               review  \
# 0  It is a 9 hour day, but if you are busy, it go...
# 1  My boss are very understanding on the situatio...
# 2  Great place to work with great people.  The ch...
# 3  I have worked on numerous Fluor projects now. ...
# 4  I am very comfortable with the work schedule t...
#
#                                                 pros                  cons  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3  Compensation was more than fair. People worked...  Time away from home.
# 4                                                NaN                   NaN
#
#    rating  yes_helpful  no_helpful      industry
# 0     5.0            0           0  construction
# 1     5.0            0           0  construction
# 2     5.0            0           0  construction
# 3     5.0            0           0  construction
# 4     5.0            0           0  construction

# %% [markdown]
# ## Clean Job Titles

# %%
import string
import re

replacement_words = {
    "it":"technology"
    ,"sr":"senior"
    ,"qa":"quality"
}

translator = str.maketrans(string.punctuation, ' '*len(string.punctuation)) #map punctuation to space
def cleanTitle(title):
    title = str(title).translate(translator)
    title = re.sub(' +', ' ',title)
    title = title.lower()
    title_split = title.split(" ")
    for key, value in replacement_words.items():
        title_split = [ value if key == word else word for word in title_split ]
    return " ".join(title_split)

reviews["clean_job_title"] = reviews.job_title.apply(cleanTitle)


display( reviews[["job_title","clean_job_title"]].head() )
# Out:
#                                   job_title  \
# 0  Principal Process Engineering Technician
# 1                     Journeyman Pipefitter
# 2        Systems Engineer and IT Specialist
# 3       General Foreman - Crane and Rigging
# 4                       Security Specialist
#
#                               clean_job_title
# 0    principal process engineering technician
# 1                       journeyman pipefitter
# 2  systems engineer and technology specialist
# 3           general foreman crane and rigging
# 4                         security specialist

# %% [markdown]
# ## Save as a pickle

# %%
import pickle
import pathlib as Path

with open("../data/all_reviews.pkl","wb") as f:
    pickle.dump(reviews,f)

# %% [markdown]
# ## Example how to use pickle

# %%
import pandas as pd
import pickle

with open("../data/all_reviews.pkl","rb") as f:
    reviews = pickle.load(f)
    
display(reviews.head())
# Out:
#   company_name                              review_title  \
# 0  Fluor Corp.                         fun place to work
# 1  Fluor Corp.                              Im satisfied
# 2  Fluor Corp.  New and intellectually stimulating work.
# 3  Fluor Corp.         For me.... GREAT group of people!
# 4  Fluor Corp.       Good place to work in a Combat Zone
#
#                                   job_title   employee_status  \
# 0  Principal Process Engineering Technician   Former Employee
# 1                     Journeyman Pipefitter   Former Employee
# 2        Systems Engineer and IT Specialist  Current Employee
# 3       General Foreman - Crane and Rigging   Former Employee
# 4                       Security Specialist   Former Employee
#
#             location        date  \
# 0     Sugar Land, TX  2020-02-03
# 1  Crystal River, FL  2020-04-05
# 2    Aliso Viejo, CA  2020-04-05
# 3      Deer Park, TX  2020-04-04
# 4        Afghanistan  2020-04-04
#
#                                               review  \
# 0  It is a 9 hour day, but if you are busy, it go...
# 1  My boss are very understanding on the situatio...
# 2  Great place to work with great people.  The ch...
# 3  I have worked on numerous Fluor projects now. ...
# 4  I am very comfortable with the work schedule t...
#
#                                                 pros                  cons  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3  Compensation was more than fair. People worked...  Time away from home.
# 4                                                NaN                   NaN
#
#    rating  yes_helpful  no_helpful      industry  \
# 0     5.0            0           0  construction
# 1     5.0            0           0  construction
# 2     5.0            0           0  construction
# 3     5.0            0           0  construction
# 4     5.0            0           0  construction
#
#                               clean_job_title
# 0    principal process engineering technician
# 1                       journeyman pipefitter
# 2  systems engineer and technology specialist
# 3           general foreman crane and rigging
# 4                         security specialist
