# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint
import pickle
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import nltk
from nltk.corpus import wordnet as wn
#nltk.download('stopwords')
#nltk.download('wordnet')
# spacy for lemmatization
import spacy
from spacy.lang.en import English
parser = English()

# Plotting tools

import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import pickle

with open("../data/tech_review_sent_corpus.pkl","rb") as f:
    tech_review_corpus = pickle.load(f)
    
display(pd.DataFrame(tech_review_corpus).head(10))

reviews = pd.DataFrame(tech_review_corpus).review.tolist()

#reviews = list(map(str.split, reviews))
# Out:
#    index                                             review
# 0    299          great company people care make difference
# 1    299  management care employee well providing contin...
# 2   1145              powerhouse epc went heavy worksharing
# 3   1145  send much work overseas possible keep core person
# 4   1145                    heavy loaded company management
# 5   1145            chase project hire thousand oil booming
# 6   1145                            turn lay thousand going
# 7   1145                       sharpest spike hiring laying
# 8   1145                    employee clearly greatest asset
# 9   1375                                     much could add

# %%
reviews
# Out:
# ['great company people care make difference',
#  'management care employee well providing continued learning opportunity',
#  'powerhouse epc went heavy worksharing',
#  'send much work overseas possible keep core person',
#  'heavy loaded company management',
#  'chase project hire thousand oil booming',
#  'turn lay thousand going',
#  'sharpest spike hiring laying',
#  'employee clearly greatest asset',
#  'much could add',
#  'enjoyed working people working',
#  'loved',
#  'hour great flexibility needed',
#  'place pretty boring time interesting facility uranium enrichment almost half century',
#  'everyone hurry get thing done hurry part make sure get need get done',
#  'typically 3 level removed customer actually work',
#  'hire',
#  'term would rate 4',
#  'hired nice intelligent people',
#  'reasonably pleasant place spend 40 hr per work',
#  'infrastructure adequately maintained except maybe escalator',
#  'could also rate bos time rated',
#  'benefit better average',
#  'project reasonably well managed',
#  'returned rate 3 pension performance appraisal process lost objectivity',
#  'could longer holiday time',
#  'many process software tool old cumbersome poorly implemented',
#  'project guideline often align company established process',
#  'found frequently saying simple error easy correct',
#  'much quicker lay',
#  'leaning heavily workshare foreign office',
#  'building accomodate 1200 people according last rumor heard',
#  'longer growing',
#  'hated working company',
#  'pay great management utterly horrible',
#  'people would punished taking away scheduled leave',
#  'interesting day work enjoyable environment',
#  'user coddled understanding technology',
#  'machine often broken',
#  'management handle well',
#  'challenging place work manager five office 200 user sole support entire infrastructure',
#  'decent pay good benefit',
#  'need willing relocate every couple year project generally 1 5 year would need move wherever next project',
#  'total thirty seven 37 year successful engineering experience electrical engineering construction onshore oil gas facility including lng compressor plant process plant utility plant wellpads desalination plant hv lv infield substation refinery infield equipment skid platform tank farm pipeline overhead hv distribution line rtu site cross country pipeline network oil gas offshore platform jacket including processing platform production platform compressor platform drilling platform gas treatment platform water disposal platform substation platform living quarter platform helideck connecting bridge flare stack petrochemical plant utility facility infrastructure industrial commercial medical hotel residential building sport complex facility rapid transport system telecommunication facility mining facility including infrastructure',
#  'work lead engineer approximately nine 9 year project management consultant pmc approximately six 6 year supervisor approximately two 2 year engineer approximately eighteen 18 year',
#  'project worked located queensland australia abu dhabi uae copiapó chile hai phong city vietnam al khor qatar jakarta indonesia doha qatar kuala lumpur malaysia bahia blanca argentina kertih malaysia batu hijau indonesia kingdom saudi arabia manila philippine',
#  'short time experience great',
#  'typical full surprise',
#  'supporting system never dull',
#  'offer position throughout world importantly take care employee',
#  'everything providing cupcake everyone employee appreciation',
#  'great company work',
#  'experience flour engineering construction co pretty cool',
#  'really enjoy work environment management concern employee health safety regular training programme meeting made improve work effiency attitude',
#  'always treated respect given responsibility',
#  'trusted supported management',
#  'given task supervisor knew result would never check work would issue construction',
#  'client never made made comment document fact chevron gave recognition award always ssscheduleand accurate document issued construction',
#  'like large shop politics challenge experience environment within company enjoyable professional supportive',
#  'management great staying way solution execution even better listening clearing resource financial logistic hurdle',
#  'opportunity endless',
#  'definitely place get get rewarded effort put',
#  'reason left company relocated coast',
#  'many good year sorry leave due downturn manager say welcomed back workload increase',
#  'typical receiving updated information coming event job contract may affect current workload effect job direction',
#  'good hand alert unforeseen obstacle possible problem could effect work progress',
#  'timely regularly staff meeting great opportunity discus current work concern upcoming milestone discus important project detail could help production progress',
#  'learned many thing job better handle multi project simultaneously avoid stress come inevitable matter immediate control',
#  'enjoyable part job work completes timely manner minimal interruption outage service',
#  'placing customer concern complete satisfaction',
#  'great compensation opportunity travel learn ambitious recommend anyone want get engineering',
#  'challenging well worth effort',
#  'work environment really competitive feel pressure time time since working application deployed globally',
#  'work culture relaxed long work',
#  'work time flexible long get work done',
#  'company really great place work unfortunately contributes difficulty finding advancement',
#  'low turnover rate promotion opportunity happen often generally wave top person leaf several people move chain reaction',
#  'tend pay title alignment job looking job leave looking bit underqualified title',
#  'far worst management staff ever worked',
#  'another government program full waist resource',
#  'half employee paid half paid',
#  'working wtp wpp rewarding experience',
#  'learned great deal integrated daily life go well beyond technical skill',
#  'company great job security people opportunity company',
#  'away house 12 hour get paid 9',
#  'management great delegating work others constantly fighting fire instead planned work',
#  'great place work',
#  'excellent work environment ethic',
#  'lot thing learn co worker engineer around world',
#  'co worker really nice comfortable plenty opportunity learning skill',
#  'management efficient',
#  'work life balance great people fun work',
#  'positive experience company unfortunately lost contract live relocate stay',
#  'great company work',
#  'cant say enough good thing',
#  'happy',
#  'political company nature',
#  'revolving door employee coming employee removed',
#  'dress well charge overtime hear',
#  'place lot scope learning technology',
#  'timing good leasure play activity',
#  'regular outing',
#  'amazing work life balance',
#  'great exposure',
#  'really let autonomy',
#  'management really believe helping achieve goal',
#  'flexible hour',
#  'hurrah',
#  'culture great get learn lot really push get thing adopted tested',
#  'learning opportunity fought',
#  'work life balance great benefit lacking',
#  'compensation also competitive promotion raise clearly marked',
#  'toxic environment management leadership top look employee',
#  'non technical politician looking benefit',
#  'completely behave opposite home depot orange core value teach expect employee learn apply core value',
#  'select people based race skill talent',
#  'lost kindness human play role always show respect manager without expecting gaining anything',
#  'wish never worked home depot worse place worked 20 year experience software',
#  'please make sure manager race color otherwise right',
#  'different race color majority home depot place work',
#  'support working one standing',
#  'great work environment',
#  'company provided support store employee made job lot easier talk inside employee',
#  'great place work management drinking kool aid become sweat shop',
#  'using cutting edge moved cloud',
#  'company passive aggressive treat employee threaten confront issue',
#  'poor management',
#  'retail',
#  'base pay determined corporate',
#  'pay raise le quarter',
#  'lot teenager need parttime job load bad personality low productivity',
#  'management try hard retain motivated individual pay reflect workload 150 coworkers make life miserable',
#  'good management improves morale',
#  'lot free food holiday special event',
#  'probably retail job could',
#  'home depot home improvement retailer nearly 400 000 staff 2 200 store canada mexico',
#  'hope depot leverage emerging tool technology support dynamic iterative business development practice',
#  'database administration consistently challenged design demand driven architecture database model deliver industry leading database structure configuration database recovery strategy security high availability ensures integrity security drive future organization',
#  'member take ownership work part empowered balanced database administration',
#  'time home depot moved different department 5 time without applying position requesting transfer',
#  'includes engineering specific division support l3 support',
#  'team practice agile development pair programming',
#  'really trying start atmosphere job security fortune 500 company',
#  'home depot great company work',
#  'lot encouragement technology folk oriented',
#  'time company face problem corporation',
#  'good company work',
#  'pair programming environment',
#  'good job security',
#  'lot sport room',
#  'excellent environment grow',
#  'one exptin life',
#  'great company',
#  'always date',
#  'good benefit place work atlanta ga',
#  'good place individual develop skill learn',
#  'work culture great always people willing assist hire',
#  'company good work life balance okay compensation',
#  'unless work e commerce might working technologically conservative',
#  'talk lot trying beat amazon willing take actual step get',
#  'trying claim compete technology company home depot actually surprisingly large amount people code department holding title software engineer',
#  'could problem team someone code leading project relies contractor also equally incompetent coding',
#  'however team working cutting edge technology tool',
#  'make sure get right disappointed',
#  'great place work',
#  'fun environment game fun activity',
#  'many way learn technology',
#  'work home management understand need leave take care personnel business',
#  'good reasonable salary collaborative unlimited sick leave bad employee get 10 vacation day company observes 6 paid holiday year',
#  'mixed feeling latest time thd',
#  'found much surprise enjoyed pair programming immediately felt useful',
#  'instead left flounder paired different developer week someone group long enough knowledge go help',
#  'part job fantastic',
#  'however open environment good anyone talk',
#  'often people comment thing meant heard',
#  'also extremely hard think concentrate',
#  'addition language communication barrier',
#  'great culture',
#  'vision value taken pride excellent opportunity growth advancement great benefit excellent people',
#  'highly recommended',
#  'home depot provides safe work environment filled opportunity advancement',
#  'everyday challenge chance advancement within company personal goal',
#  'really good benefit',
#  'fun extra curricular activity',
#  'mix diversity difficult customer would probably hardest part job enjoyable part lunch house',
#  'enjoyed time thd however believe manager qualified needed improve',
#  'felt way work within company',
#  'one department apply company whole',
#  'considerable bureaucracy regulatory constraint reduce pleasure job experience considerably',
#  'come large fortune 50 company comfortable',
#  'hand spent lot working time smaller company eventually tire artificial challenge imposed activity bureaucracy regulatory constraint constantly maneuver around job',
#  'productive free environment',
#  'exposure technology',
#  'work life balance',
#  'work count hour',
#  'professional fun experienced people around',
#  'management proactive agile xp involving team different activity',
#  'open platform opinion',
#  'customer interaction customer satisfaction',
#  'relaxed atmosphere developer start',
#  'le pressure unrealistic deadline give story',
#  'freedom trust work',
#  'liked working home depot',
#  'okay part',
#  'loved working friend',
#  'benefit high gym really nice',
#  'productive well deserved sr',
#  'java developer home depot usa',
#  'got experience skill home depot management good',
#  'home depot director client enjoyed built skill',
#  'company worked agile system quite interesting',
#  'management kindful help whenever need',
#  'company routinely talk paying accordance industry standard clearly bottom end standard',
#  'work make sure negotiate coming door avoid hr area one low ball financially',
#  'company also great promoting within poor job developing leader',
#  'decent benefit good networking opportunity relationship building opportunity good overall taking care people culture',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'outside hr',
#  'productive fun',
#  'good colleague wonderful environment work',
#  'working home depot seven year lot learn deliver job',
#  'fast paced environment offer various opportunity advancement',
#  'home depot truly life value taking care associate',
#  'organization midst transforming software engineering iterative environment',
#  'good company work management good arent associate dont reap benefit company',
#  'good way start',
#  'charge designing framework full automation suite homedepot e commerce space',
#  'also incharge experiment open source technology service team',
#  'company undergoing lot change group',
#  'hit miss whether group pigeon holed thing x number year',
#  'developer enjoys pair programming 40 hour week love',
#  'challenging interesting workplace fun',
#  'typical work learning take away',
#  'management understanding cooperating',
#  'workplace nice good understanding',
#  'enjoyable part nice game option',
#  'place say learned lot technical stuff net coding',
#  'entire helping nature manager super cool personality',
#  '',
#  'home retailer home improvement construction product service',
#  'operates many box format store across state including 50 u state district puerto rico state virgin island guam ten province canada well mexico',
#  'company headquartered atlanta store support center cobb county greater atlanta',
#  'home depot great company work',
#  'learn much company associate work',
#  'often time feel like oriented place work oppose corporation',
#  'culture applies lower level',
#  'feel comfortable giving feedback product decision management etc',
#  'come look monitoring see device went line',
#  'would call site someone check',
#  'call att sprint circuit issue',
#  'would proceed troubleshoot device came',
#  'check email update ticket close ticket communicate',
#  'learned management follow protocol thats better member',
#  'co worker good people work kinda didnt want learn stuff didnt',
#  'hardest thing teach people',
#  'people home depot way longer talking 12 year longer',
#  'enjoyable part learning everyday something',
#  'loved job',
#  'good atmosphere',
#  'nice people',
#  'political',
#  'work life balance actually pretty decent',
#  'good pay decent benefit',
#  'personally like position everyone helpful part',
#  'usual work place',
#  'work whenever required time matter',
#  'like 24x7 working environment anytime open laptop start work',
#  'great working environment alot chance learning development',
#  'good coworkers professional attitude',
#  'fun place work application working',
#  'wouldnt work management bad abuse worker low pay trying avoid paying using whenever need stay away home depot',
#  'thd allows vendor select different type return policy credit credit',
#  'case vendor may require credit policy vendor inspection rga return good authorization vendor choose deny',
#  'partial vendor credit policy aim reduce number policy requiring rga inspection allowing thd negotiate reduced value charged vendor return',
#  'agreeing reduced charge vendor also agreeing wave requirement rgas inspection product agreeing dispute particular return policy',
#  'thd allows vendor select different type return policy credit credit',
#  'case vendor may require credit policy vendor inspection rga return good authorization vendor choose deny',
#  'partial vendor credit policy aim reduce number policy requiring rga inspection allowing thd negotiate reduced value charged vendor return',
#  'agreeing reduced charge vendor also agreeing wave requirement rgas inspection product agreeing dispute particular return policy',
#  'enjoy environment like place needed',
#  'good company poor pay',
#  'contractor paid significantly low',
#  'high turnover rate',
#  'get benefit decide keep',
#  'people great excellent training program',
#  'leaned lot company great place work',
#  'management great helpful employee concern',
#  'people workplace friendly helpful lovable',
#  'constantly driving towards cutting edge technology',
#  'scrum based project',
#  'enjoyed time home depot hour middle night became problematic',
#  'indoor gymn indoor cafeteria',
#  'company also provided training lot area',
#  'good work leader vision',
#  'lot learning implementation idea',
#  'good work environment',
#  'maybe probably worst place ever worked',
#  'put hardware love hardware always got 1000 call 5 7 pm',
#  'always 1000 call',
#  'many people',
#  'lucky 25 people',
#  'team handled software 40 people handled 300 call',
#  'even think looking non work related website write',
#  'cell phone visible desk vibrate mode',
#  'write',
#  'forced work late cause 1 hour call right end shift',
#  'write',
#  'forced kill overtime',
#  'two type worker contractor employee',
#  'employee work home depot contractor work contracting job home depot',
#  'treat contractor like living trash',
#  'contracting manager would mail weekly letting know employee would getting free meal live mariachi band chance win 1000 saw allowed participate',
#  'contractor treated like trash unless chosen hired employee',
#  'even local hardware software manager would treat like dirt',
#  'call worst hope like get berated cashier worst attitude',
#  'need register running cannot use working register side',
#  'probably one worst corporate culture seen',
#  'coming fast paced productive startup environment exact opposite',
#  'dress code business',
#  'stack behind 10 year management responsive adopting modern software development practice',
#  'manager dinosaur year could care le improving development process loaded unnecessary bottleneck',
#  'manager lead developer position come development background liasons business',
#  'offshore developer create poor quality product everyone firefighting mode fixing bug production due poor software development practice',
#  '8 30am monday meeting people talk done weekend',
#  'work 2 year modern software shop want behind',
#  'hope wonderfull palce work',
#  'everything work place pleasent great',
#  'learned lot retail business management support encourages grow every individual',
#  'co worker good cooparative hard time moving microstratgey server atlanta huston faced lot difficlties manager production server',
#  'way enjoyable time job place',
#  'love fact stable job company really care help need',
#  'work isnt hard always willing take task',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'instability housing market brought company',
#  'probably return',
#  'currently working itis infrastructure support engineer technical lead',
#  'providing l3 level support unix linux server',
#  'handling triage call break',
#  'allocating request ticket member shift basis',
#  'generate metric report remedy ticketing system automation stuff manual effort',
#  'good knowledge trouble shooting various application like java jsp servlet pl sql sql query unix scripting perl',
#  'good understanding technology thats learned many technology short spam time',
#  'conduct weekly meeting client stake holder',
#  'focus improvement project stabilization',
#  'prepare root cause analysis incident store share point portal',
#  'excellent business communication good email ethic',
#  'appreciated client clear communication',
#  'interacted business user gather check online module requirement',
#  'develop sequence class diagram get approved client designing class using design pattern methodology singleton service locator dao factory session façade pattern',
#  'involved performance tuning',
#  'created front end using jsp html xml advanced javascript',
#  'used backend performed unit case component using junit configuration management clear case used',
#  'provided support user acceptance testing performance testing',
#  'ga vinings building shelter 8000 employee clean many amenity gym roo cafeteria appointed chef',
#  'friendly environment wonderful staff love job helping customer troubleshooting figure resolve issue hand',
#  'worked company operated warehouse enjoyed working year',
#  'would come starting taking call agent insured assist understanding policy billing',
#  'learned great deal insurance work effect people',
#  'management great every would get manager try thing way quickly adjust way thing prior',
#  'least 6 7 supervisor due rearranging team',
#  'hardest part job getting training time product',
#  'would usually get month later would make tough explain',
#  'enjoyed everything',
#  'great company work',
#  'good job easy work',
#  'find another job could get hour higher wage',
#  'involved complete sdlc software development life cycle plan analyze design build test rollout implementation phase',
#  'designed application using model view control architecture',
#  'involved client side development using html javascript cs',
#  'used strut validation framework validate request coming form',
#  'developed ui using jsp interactive cross browser functionality complex user interface',
#  'developed jsps multiple view presentation layer servlets business layer java bean sessionbeans ejb model layer',
#  'dao design pattern used persisting database 9i',
#  'implemented logging mechanism using log4j',
#  'used rad ide tool code development debugging deployed application websphere application server',
#  'environment java 1',
#  '4 j2ee ejb jsp servlets xml javascript cs mvc dao strut validation framework junit webshere application server 6',
#  '0 tomcat 2',
#  '0 webserver log4j 9i window xp',
#  'working home depot experience uncanning',
#  'learning process timely return processing closely working vendor',
#  'moral plus',
#  'one place ever worked good salary compensation programme',
#  'responsible installing sql server database instance environment',
#  'responsible supporting sql server database ensuring performance availability security',
#  'responsible ensuring availability performance database support system',
#  'work ensure associated hardware resource allocated database ensure high availability optimum performance',
#  'responsible improvement maintenance database include deployment upgrade',
#  'responsible security non security patch based company approved maintenance schedule',
#  'enjoying learning curve various opportunity',
#  'great company flexible learning opportunity diversity much growth carrier advancement good management immediate pay raise changing role',
#  'location mostly remote construction site',
#  'training safety top priority',
#  'work start 6 mostly end around 6 pm mostly',
#  'good people work management somewhat distant',
#  'good place learn construction trade training continuous',
#  'whole great company unfortunately executive director level leadership within technology group hardly called leader',
#  'still much good ol boy place work people mostly rewarded previously working corp',
#  'vp seems good idea want take org clearly figured get direct report page',
#  'company boast effort investing people technology group really good grasp effectively',
#  'probably noticeable complete lack real leadership',
#  'given walk hall witness large number employee sitting around much anything',
#  'director fall asleep desk routinely get promoted anyway',
#  'employee year working still could figure actually company',
#  'direct supervisor famously known either unable incapable unwilling make sort meaningful decision anything',
#  'hopefully thing within technology group bring leadership talk show company deserves better',
#  'offshore based great place work environment professional company give opportunity grow',
#  'work ready call even',
#  'pay great health benefit second none',
#  'also employee retirement plan great providing make 5 year fully vested',
#  'employment longevity good 75 percent people worked last three year either laid quit',
#  'like working hard rewarded nicely commit working',
#  'employee ownership plan real reward nicely willing commit company working hard long hour moving job',
#  'everyone',
#  'really good exiting working latest technology',
#  'gave good platform start work tabular model dax',
#  'overall group moving forward building policy procedure',
#  'step careful quantity quality',
#  'communication still need improve better move forward',
#  'collection started overall process planning follow footstep',
#  'valuable work enviorment',
#  'fresher lot opportuinity experienced give exposure',
#  'good category employee',
#  'strongly recommended',
#  'typical included providing support past client current rf engineer used rf planning software',
#  'also entailed adding feature working rf planning service asp net c',
#  'hardest part job finding support application transition rcc veatch',
#  'learned work independently tenure veatch',
#  'bv good place start fresh college',
#  'however anyone ambition intelligence leaf within 3 year',
#  'stay slug way middle management position make life miserable everyone around',
#  'paper pushing finest',
#  'great place great people',
#  'enjoyable part everyone attitude great willing help',
#  'great company work inc',
#  'provided insight opportunity work carolina rotating technician',
#  'workplace culture excellent supportive',
#  'much balance work personal life dedicated good manages',
#  'good place developer enhance skill',
#  'company large tends operate low end telecom mean type individual typically support technician installing piece rate equipment low hourly clip',
#  'enjoyed fast paced work heavy work load',
#  'little time',
#  'work multi tasking position provided',
#  'however internal discord employee high turn rate',
#  'made difficult settle position',
#  'somewhat intern treated like full time permeant employee',
#  'department structured organized',
#  'falling every morning regardless weather counterproductive role call like military',
#  'lunch break standardized shift timing overtime',
#  'hard stop pt already job two hour',
#  'continuous pressure get work done correctly sub without additional fund',
#  'emphasis safety morale',
#  'always someone watching',
#  'company focus seems employee well',
#  'seems every several year regime manager employee different company come stir thing step many good longtime employee find ousted',
#  'layoff unfair especially longterm employee family',
#  'believe sort monitoring process look reason person selected laid protect terminated simply may disliked',
#  'typically high manager direct manager',
#  'support employee assist claim wrong even though taught way',
#  'terrible place work send anyone know',
#  'may pay okay money claim get bonus even though well impossible achieve kiss good bye',
#  'looking stay one location job',
#  'cutting technology fortune 500 company',
#  'interned 6 month blast learning exposed corporate work life',
#  'much know besides fact great environment intern ensured understood work life',
#  'many employee really long time 10 year open technology idea input employee lot experience',
#  'management trying culture slow',
#  'people friendly',
#  'work life balance good',
#  'software system slow old need major overhaul',
#  'mid level net developer would good place grow skill low key environment',
#  'company financially stable weathered recession well',
#  'day consisted computer every',
#  'worked updating people software fixing application problem may',
#  'manager patient walked issue came across',
#  'offered guidance whenever needed absolute delight work',
#  'loved every single',
#  'co worker kind never minded casual conversation ran',
#  'hardest part job people short handed patience',
#  'made job difficult feeding frustration',
#  'loved place people',
#  'great company work area',
#  'lot opportunity growth skill set used slightly antiquated',
#  'company struggle use modern practice primarily aged workforce also often forced use doe standard',
#  'typically work 10 hour 3 hour inevitably spent sort meeting safety briefing site wide notice',
#  'two hour used socializing waiting people call back lunch',
#  'rest time used get work done ala project working need signed management three different department one manager fishing trip two week',
#  'least give unlimited subscription computer science site publication spend time learning skill get next job much quicker',
#  'choose skill reason sit hand fear rarely fire people desperate warm body',
#  'workplace culture quiet acceptance choking inefficiency unreliability dilapidated system site',
#  'given stick stone issued watch boss given latest iphones supercomputer workstation send group email chain',
#  'make time working hard polishing resume',
#  'thing advancement traditional sense closer waiting people retire desperately asked someone else job else everything explode literally',
#  'good bos excellent time like',
#  'part site mismanaged though',
#  'programming pretty decent experience',
#  'site security pretty high newest technology may available',
#  'problem programming lot project would pushed onto one person',
#  'meaning person left project got dumped someone else desk organization tree',
#  'also group specifically lack employee hired develop full stack even though started job back end dev',
#  'also testing subpar code quality suffered since lack member dedicated testing qa code quality',
#  'project would abandoned due lack able push time would stuck constant testing loop final release',
#  'due one 2 devs one job',
#  'loved member work',
#  'part',
#  'security clearance process kind long pain job promotion may hold 3 year may get fired get clearance',
#  'management horrible',
#  'stuck old way software development',
#  'go military checkpoint entering leaving site',
#  'middle limited option lunch',
#  'software development srns would expect large contractor doe',
#  'cannot speak site whole employee corporate department professional competent',
#  'opportunity learn latest tool technology however minimal',
#  'project happened assigned would considered maintenance work',
#  'contract perm seems common',
#  'offered position steep cut contract rate accept offer',
#  'experience srns assigns pay grade based almost entirely education year experience rather performance',
#  'work generally self paced consists range web based client server application',
#  'responsible maintenance bug fix several dozen java application',
#  'technology use employment included flex jsp jquery',
#  'developer permitted use version control open source tool official policy group',
#  'great job 20 time spent maintenance activity upgrading trouble shooting problem making minor enhancement 30 time spent coding apps utility 30 time spent migration consolidation existing software system site wide system 20 time spent consulting type activity',
#  'great experienced manager exist throughout organization',
#  'hardest part job getting bureaucratic hurdle exist within government related work',
#  'enjoyable part job solving technical problem putting place software solution realize monetary saving company',
#  'department isgreat someone seeking opportunity growing company',
#  'referral oreinted company well',
#  'veteran friendly also',
#  'overall good choice south end local south carolina person',
#  'started great place work advanced tremendously',
#  'however management started outsourcing lot work hire full time employee',
#  'understaffed size company',
#  'also recent organizational change well liked coworkers led longer working hour stress',
#  'department tend promote within would rather find third consultant vendor outside experience',
#  'want bash',
#  'working helped grow technical skill tremendously however current managerial trend paint somewhat bleak picture department future',
#  'operation management incompetent 3 stooge care job company customer definitely employee',
#  'home builder mortgage provider high employee turnover',
#  'great place come get experience home sale home building moving good job',
#  'company allowed come entry level position learning customer company given opportunity grow direction wanted network engineering',
#  'three year able move tier 3 network engineering spread wing dream',
#  'involved development sale navigator 2 project',
#  'worked user interface layer styled existing web page using html cs javascript',
#  'involved development access layer business logic layer middle tier user interface front end using net framework 4',
#  '0 c visual studio 2010',
#  'worked iterative agile methodology used server side asynchronous javascript jquery xml ajax technique improve performance',
#  'created project v effective collaboration',
#  'created consumed wcf service',
#  'used linq entity retrieval wcf',
#  'used ajax script manager update panel partial update make ui responsive',
#  'performed ui testing navigation testing unit testing regression testing',
#  'used linq sql feature net framework retrieving sql server',
#  'wrote several validation client side function using j query',
#  'developed report using ssrs thorough analysis inventory',
#  'designed developed parameterized report linked report matrix tabular report drill drill drop menu option using ssrs',
#  'typical work place good co worker',
#  'short break',
#  'process oriented good ethical atmosphere',
#  'corrosive business culture promotes nepotism',
#  'technology manages fear engineered lack communication use culture form control',
#  'technology good place work drove around wisconsin surround state picked dropped electrical equipment tool',
#  'also helped performing work area setting various equipment',
#  'met lot people co worker',
#  'also laid due company',
#  'lot focus teaching employee culture company',
#  'vision mission value',
#  'disc behavior assessment tool focus company',
#  'lot training available company benefit good',
#  'use pto paid time',
#  'start 2 week vacation plus sick day',
#  'pto available immediately',
#  'stressful time',
#  'retired miss',
#  'awesome benefit people',
#  'job rarely went totally way planned never boring',
#  'nature job driven great emergency',
#  'long environment fairly quiet place staff easy going',
#  'application communicating issue utilized people tend call contact info anyone looking number see actually done',
#  'assisted analysis design phase',
#  'implemented change modification like iterative incremental development',
#  'developed web page using asp net c',
#  'implemented multiple web service feeding application',
#  'integrated xml schema web service make xml document',
#  'used cs attain uniformity web page',
#  'used javascript ajax client side validation rich user experience',
#  'implemented access layer involved writing maintaining complex sql query required stored procedure trigger',
#  'enjoyed company knowledge acquired coworkers',
#  'pay good',
#  'would recommend company others would accept another position future',
#  'must fast foot',
#  'test trial fire',
#  'working location toxic always seemed like people get',
#  'job one enjoyed',
#  'made mistake going better judgment accepting promotion network manager entire company',
#  'utah branch network administrator position wide range job responsibility multiple location support enjoyed great respect management',
#  'great place work',
#  'good cio practically destroyed department dishonest practice',
#  'replace 2 year quit',
#  'management heavy company employee long tenure 10 40 year',
#  'employee 4 level management c level executive business line',
#  'work home program old policy little management',
#  'place well organized efficient',
#  'worker great work',
#  'working 10 hour shift friday friendly 3 weekend',
#  'company good company work',
#  'pleased recommended company friend',
#  'call without issue',
#  'zimmermann good company work',
#  'provided training necessary part believe keeping employee marketable',
#  'oriented place work',
#  'everyone working goal',
#  'working z described gathering purpose gain profit get work done manner say',
#  'worked operating unit subsidiary',
#  'brand moving speed light',
#  'love challenge maintain pace fantastic company grow',
#  'company really good',
#  'people nice much respect show return',
#  'slow deliberate move made rushing around',
#  'good work company safety orentated committed safety quality work cost schedule mind',
#  'company us continuious improvement program',
#  'throughout hiring process various team informed role responsibility',
#  'onboarded quickly realized described sold way aligned job description',
#  'role much junior sold much influence',
#  'management disorganized including extremely lack leadership',
#  'honest employee regarding position',
#  'need leadership',
#  'one biggest construction company canada',
#  'many intelligent people work lot experience',
#  'good place get foot wet construction',
#  'regard employee business',
#  'understood get work done several way handle scenario issue lieu done',
#  'bureaucratic probably large size different business',
#  'almost chance progress dealt wrong hand senior management',
#  'lot play favorite really take care employee others like employee exist',
#  'senior execuitve seems oblivious company led exec',
#  'lot vp thing align executive message culture',
#  'exec agenda',
#  'think pay employee overtime intentionally',
#  '3 stretch workded 17 hour 19 hour 21 hour',
#  'taking employee handle hiring people',
#  'would work',
#  'especially employee',
#  'amazing place work',
#  'culture everything',
#  'experienced professional',
#  'love people attention safety ship come',
#  'work system administrator normally time come go back job nature',
#  'lot training management',
#  'friendly respectful atmosphere',
#  'learn almost every something regarding job',
#  'opinion salary ok benefit ok people trusted',
#  'opinion technology way behind many consultant making mess major project like cost company million',
#  'opinion leadership lot learn connect people treat',
#  'opinion internal training program hr much especially disruptive employee addressed timely manner many case even promoted',
#  'many executive still around',
#  'non performing employee kept around',
#  'management listen expert',
#  'much money wasted poor technology',
#  'hr actually support people',
#  'question survey never really addressed',
#  'nobody see executive hr finance get along',
#  'fishel honest value live value',
#  'treat teammate',
#  'company fair really want make difference',
#  'construction company lot turn staff',
#  'fishel want continue grow continually try find opportunity',
#  'right circumstance good place grow',
#  'working qatar w helped evoolve technical support engineer term variety training course enrolled',
#  'typical work started 8 staff meeting set agenda starting prepare needed document fulfilling task within time line set',
#  'co worker world different culture opinion',
#  'hardest part job quick turnover task one biggest sale engineering company',
#  'always provided enough break time outdoor activity hat helped building great spirit',
#  'company worked till date',
#  'starting product training hand practice entire work culture company',
#  'always seek make talented people grow higher position take challenging rewarding role',
#  'following ethical practice deal customer well employee',
#  'could enjoy work happy see value mission company',
#  'held job short time left company due long daily commute',
#  'company belief training safety making sure employee company vision',
#  'learned much short tenure continue use skill acquired every single',
#  'work environment highly competitive due construction culture',
#  'everyone work hard encouraging communication one aspect',
#  'communication moment given project exceptional',
#  'reward hard work job constantly recognized expected',
#  'working building company learned many tip help computer hardware software',
#  'learned help customer find solution via phone email',
#  'also learned talk customer fixing computer',
#  'day work project assigned',
#  'working mostly occasionally working others help issue',
#  'learned lot coding web application back end front end',
#  'supervisor kept date progress making also made clear explain needed work',
#  'co worker work many time help issue share idea improve web application project working',
#  'hardest part job learning sql mixing c visual basic language skill taught previously',
#  'taken challenge full work improve aspect fall',
#  'part job finishing web application seeing work went watching final product produce result expected',
#  'department lacked direction organization',
#  'constant issue cause outage customer frustration could fixed management easily',
#  'overall average experience',
#  'start 9am est learnt lot thing nvr',
#  'lot support lead co worker',
#  'whenever faced difficulty work lead co worker always helping hand',
#  'typically helpdesk essentially serve face',
#  'depending upon skill willingness learn possibly move advanced help desk position',
#  'however type advancement limited due size dept',
#  'time company taught one facet larger volume inbound call handled',
#  'also able expand knowledge larger corporate network operates',
#  'co worker excellent work company without flaw',
#  'hardest part job complexity daily process adding user replacing pc far complex',
#  'enjoyable part challenged daily basis either complexity job issue faced',
#  'one worst company ever worked',
#  'company bad politics every one trying pick back stab',
#  'pm stupid dum doesnt even remember exactly person start working task',
#  '',
#  'company full indian people play politics focus work',
#  'lousy developer architecture cant even figure error coding causing error',
#  'whole building empty like ghost town',
#  'old folk left company 20 year',
#  'many people declined company offer job due many indian people bad politics',
#  'one worst experience ever',
#  'management terrible company implode',
#  '',
#  '',
#  'slowly eliminating department job position',
#  'ownership try breath life inevitable',
#  'apply elsewhere',
#  '',
#  '',
#  '',
#  '',
#  'much job security people get let go routinely',
#  'pay raise several year',
#  'manager blame',
#  'manager make policy look reason terminate associate especially woked long time',
#  'also lot favoritism shown certain associate people looked qualified position given others le qualified lacked knowledge',
#  'holding interesting place work',
#  'always learn see much availability moving',
#  'direct management wonderful nice willing work higher ups company exactly opposite',
#  'enjoyable fun place work',
#  'fast paced busy',
#  'people nice respectful around',
#  'environment comfortable',
#  'good time working',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'pay compensation good',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'work environment friendly competitive',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'learnt lot',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'pretty good company',
#  '',
#  'could better pay definitely enjoy time employment',
#  'would still closed retail affiliate',
#  'management kinda racist 100 show favoritism',
#  'promote someone experience skill within company would hire friend promote friend within 2 month even though company policy state transfer another department get promotion least six month getting hired',
#  'going downhill',
#  'hire technical specialist expect sale person much top little pay',
#  'high stress environment way much management',
#  'stayed almost end',
#  'call center high turn rate lay offs happened would performance standard unrealistic goal next would see 4 5 empty seat',
#  'talk center closing job fantastic',
#  'working goal bonus great',
#  'benefit lot commission easy make work incentive',
#  'work hour flexible could add shift work overtime needed',
#  'truly enjoyed job',
#  'management always lot pressure hindsight likely center going',
#  'manager trying keep morale help slower people catch could tell stress getting manager disappearing every',
#  'work one center still open thinking time training get involved workplace drama job',
#  'fast learner self motivator able work mostly think applying',
#  'lot time receive monthly feedback get back track',
#  'wonderful company work long continuously keep job issue',
#  'stock option 401k health insurance vision insurance dental insurance',
#  '',
#  '',
#  '',
#  'get lot stick',
#  'fun want leave',
#  'great company work still operating',
#  'thing tailed began struggle financially',
#  'finally reached decision outsource 2013',
#  'judgemental wear clothes think',
#  'judge even knowing',
#  'good benefit',
#  'human resource go everyone file write offs',
#  'wrote report person upper management could decide people layoff',
#  'good job people working company awful',
#  'stand policy repair appliance left lot people high dry',
#  'overcharged never right part fix appliance time',
#  'worker company policy',
#  'awful account draining policy',
#  'help overtime advancement raise time customer always get money back matter',
#  'manager never took side',
#  'almost 5 year time accumulated company took money took half 401k',
#  'experience whole unpleasant job security raise concern company concern employee',
#  'would highly recommend anyone work holding',
#  'management mostly great people',
#  'co worker seemed protest others working',
#  'going beyond job duty would hear lot whimpering',
#  'lot',
#  'come inventory cycle count',
#  'learned manage perform excellent inventory',
#  'management great always finding way improper entire unit',
#  'part peacefully calm music play softly',
#  'hardest part job change season different holiday',
#  'enjoyable part job reach goal year',
#  'working deadline fast paced',
#  'learning technician term part repair',
#  'helping customer complete order process',
#  'closed longer business',
#  'close small group individual working ensure safety technician completion customer',
#  'job culture oppressing give proper recognition top performer',
#  'fast paced relaxed environment',
#  'company oriented helpful support',
#  'try social event game month possible',
#  'people friendly helpful anything need',
#  'year cronyism ridiculously high rate contractor disproportionately large project team nobody actually ground couple good overworked underpaid people propping entire department huge restructure management perhaps understandably like rule fist make people feel threatened thinking job line work harder',
#  'people scared approach anyone ask question fear losing job',
#  'communication poor restructures constant nobody know going way management like',
#  'flexible working frowned upon one manager example got secretary record time people arrived work spreadsheet',
#  'proper process particularly non existent nobody seems care management solution fire people rather fix problem source',
#  'service desk stressed due poor decision made management handover done legacy team contracted project team worrying getting thing done time rather properly incompetent vendor',
#  'hostile environment make high turnover talented people leave',
#  'however still couple decent people left committed turning around',
#  'really want challenge might place',
#  'really enjoy working beatty',
#  'unfortunately enough development oppotunaties',
#  'generally good place work',
#  'team cliquey',
#  'supervisor excellent position others think god',
#  '',
#  'great company culture great management support work balance',
#  'great benefit perk',
#  'would strongly recommend friend',
#  'glad opportunity part',
#  'anything fire protection industry time sensitive stressful',
#  'company difficult time providing vision leadership meaningful',
#  'bought uniform worked',
#  'good company enjoyed working time',
#  'smooth transition took',
#  'worked company called uniform',
#  'workplace great well co worker',
#  'enjoyed challenge working customer',
#  'supervisor usually terrible help much unless get good one',
#  'long hour terrible transportation option due traffic time parking situation',
#  'awesome place work',
#  'innovation industry pre packaged prefab construction bim',
#  'amazingly technically savvy brightest mind industry',
#  'case point pentagon got hit industry called repair pentagon',
#  'si really great trustworthy company',
#  '',
#  'anytime government entity hire contractor sort always choose',
#  'industry far head shoulder competitor industry',
#  'company great company work purchased quikrete',
#  'company purchased took real good care employee',
#  'working definitely improved skill application developer',
#  'given challenging project right away support mentoring guidance department able create piece software benefit company long term',
#  'finished product proud possible due good cooperation teamwork management',
#  'typical consisted going work station programming whatever project priority',
#  'occasional meeting keep track progress update department development',
#  'every filled challenge',
#  'difficult resolve result well worth',
#  'learned skill sharpened one felt life part well balanced well coordinated',
#  'hardest part job learn project system unfamiliar',
#  'enjoyable part job deliver product business analyst manager receive satisfactory feedback',
#  'validates quality work',
#  'learned good management project vital part developer',
#  'management restricts funding technology development process impaired',
#  'part company need application reciprocating understanding requirement actually want end product get delayed satisfaction productivity plummet',
#  'vital ensure proper communication support developer part business need technological',
#  '',
#  '',
#  'environment fast paced one construction company',
#  'technology constantly changing keep demand user',
#  'said great company work gave many opportunity',
#  'go job developer hear warning',
#  'information service department ran someone background professional software application development environment',
#  'even worse manager friendly would invest real training build platform knowledge inside',
#  'culture lot laughter throw fire give result negative experience working company',
#  'great place work',
#  'provides great work life balance management amazing culture wonderful',
#  'enjoyed working environment could taxing due disorganization management refusal enforce policy user',
#  'learned software',
#  'originally worked hardware computer taught quite lot',
#  'co worker great every probably enjoyable part',
#  '',
#  '',
#  'fact got work computer',
#  'typical included thing like built imaged installed computer existing employee ordered set cell phone service existing employee answered incoming call network connection issue outlook issue multiple program issue anyproblem user mac pc',
#  'software installation pc set connected printer remotely ip mac pc experience active directory well exchange',
#  'define experience positive somewhat negative',
#  'worked team successful unsuccessful',
#  'amazing manager psychopath',
#  'ii good experience working client daily activity productive innovative',
#  'learned sla itil process throughout job handling process',
#  'always challenge always smart people work lot autonomy high expectation competitive lot reorganization high rate turnover stressful 24 7 online response weekend availability expected pocket political game incompetence lack accountability poor leader lack inspiration positive motivation',
#  'good work life balance good compensation good job culture',
#  'learned technology',
#  'lot thing learn',
#  'training help',
#  'great place work',
#  'mind returning role role management',
#  'made improvement skill set also opportunity others',
#  'place full backstabbing stack ranking',
#  'engineering done well junior engineer get taught lot',
#  'management slick polished',
#  'excellent work environment',
#  'innovative team follow work ethic work',
#  'great learning opportunity',
#  'place innovate create impact',
#  'really changed culture last year',
#  'great atmosphere working company',
#  'lot opportunity learn different source leadership also great attitude towards',
#  'work technology outside',
#  'different team different culture',
#  'people talented lot people bad engineer',
#  'company important every engineer come idea take risk implementing',
#  '1',
#  'team collaborative lot space personal growth',
#  '2',
#  'management really worst quite biased member especially extraordinary',
#  'fun employee',
#  'strict protocol regarding work environment',
#  'work wherever comfortable',
#  'huge campus number sport activity conducted regularly',
#  'good work environment involved working support case collaboration different time',
#  'peer helpful',
#  'flexibility work timing',
#  'awesome benefit comp package',
#  'management change frequent outside development group',
#  '4 manager year employment',
#  'great place begin',
#  'learn lot useful technology well interacting manager mate relatively relaxed environment pressure',
#  'side sometimes management poor watch good switch team good place get bad review',
#  'work design coding meeting scrum learned azure domain knowledge workspace single good focus work hardest enjoyable good collage sometime work well planed',
#  'pro innovative product',
#  'good ownership work irrespective seniority',
#  'good work life balance',
#  'good pay stock',
#  'con much politics sometimes',
#  'typical expected go 40 per week',
#  'technical growth huge learn extremely quick',
#  'management hit miss great terrible',
#  'great manager know help succeed',
#  'terrible manager wait fail allow others manage without providing input',
#  'culture diversity inclusion count protected group',
#  'example ok entire indian national entire chinese national good luck getting hired citizen',
#  '',
#  '',
#  'hardest part putting hour',
#  'put hour normal work going well',
#  'enjoyable people work really great people',
#  'full talented people management mostly suck',
#  'compensation good benefit great lot perk',
#  'silicon valley feel bit left opportunity sometimes',
#  'professional place solid engineering lot room growth may outgrow opportunity available locally',
#  'enjoy working great mind college across country',
#  'work life balance got',
#  'pay little par compared competitor',
#  'talented people around lot learn',
#  'feel proud working thing future',
#  'good place work learn everyday',
#  'get learn collaboration lot skill colleague',
#  'full opportunity growth mindset',
#  ...]

# %%
#NLTK Stop words
#nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
#extend stop word based on top 50 words
stop_words.extend(["new","lot","get","many","also","day","part","one","things","always","years","really"])

# %%
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %%
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)

# %%
def prepare_text_for_lda(text):
    tokens = tokenize(text)
    #tokens = [token for token in tokens if len(token) > 4]
    #tokens = [token for token in tokens if token not in stop_words]
    #tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
tokenize(reviews[0])
# Out:
# ['great', 'company', 'people', 'care', 'make', 'difference']

# %%
processed_docs = []
for i in range(len(reviews)):
    processed_docs.append(tokenize(reviews[i]))
processed_docs[:10]
# Out:
# [['great', 'company', 'people', 'care', 'make', 'difference'],
#  ['management',
#   'care',
#   'employee',
#   'well',
#   'providing',
#   'continued',
#   'learning',
#   'opportunity'],
#  ['powerhouse', 'epc', 'went', 'heavy', 'worksharing'],
#  ['send', 'much', 'work', 'overseas', 'possible', 'keep', 'core', 'person'],
#  ['heavy', 'loaded', 'company', 'management'],
#  ['chase', 'project', 'hire', 'thousand', 'oil', 'booming'],
#  ['turn', 'lay', 'thousand', 'going'],
#  ['sharpest', 'spike', 'hiring', 'laying'],
#  ['employee', 'clearly', 'greatest', 'asset'],
#  ['much', 'could', 'add']]

# %%
import gensim.corpora as corpora
# Create Dictionary
id2word = corpora.Dictionary(processed_docs)
# Create Corpus
texts = processed_docs
# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# View
print(corpus[:1])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1)]]

# %%
# supporting function
def compute_coherence_values(corpus, dictionary, k, a, b):
    
    lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           chunksize=100,
                                           workers = 30,
                                           passes=10,
                                           alpha=a,
                                           eta=b,
                                           per_word_topics=True)
    
    coherence_model_lda = CoherenceModel(model=lda_model, texts=texts, dictionary=dictionary, coherence='c_v')
    
    return coherence_model_lda.get_coherence()

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import tqdm
grid = {}
grid['Validation_Set'] = {}
# Topics range
min_topics = 2
max_topics = 15
step_size = 1
topics_range = range(min_topics, max_topics, step_size)
# Alpha parameter
alpha = list(np.arange(0.01, 1, 0.3))
alpha.append('symmetric')
alpha.append('asymmetric')
# Beta parameter
beta = list(np.arange(0.01, 1, 0.3))
beta.append('symmetric')
# Validation sets
num_of_docs = len(corpus)
corpus_sets = [#gensim.utils.ClippedCorpus(corpus, num_of_docs*0.25), 
               #gensim.utils.ClippedCorpus(corpus, num_of_docs*0.5), 
               #gensim.utils.ClippedCorpus(corpus, int(num_of_docs*0.75)), 
               corpus]
corpus_title = ['100% Corpus']
model_results = {'Validation_Set': [],
                 'Topics': [],
                 'Alpha': [],
                 'Beta': [],
                 'Coherence': []
                }
# Can take a long time to run
if 1 == 1:
    pbar = tqdm.tqdm(total=390)
    
    # iterate through validation corpuses
    for i in range(len(corpus_sets)):
        # iterate through number of topics
        for k in topics_range:
            # iterate through alpha values
            for a in alpha:
                # iterare through beta values
                for b in beta:
                    # get the coherence score for the given parameters
                    cv = compute_coherence_values(corpus=corpus_sets[i], dictionary=id2word, 
                                                  k=k, a=a, b=b)
                    # Save the model results
                    model_results['Validation_Set'].append(corpus_title[i])
                    model_results['Topics'].append(k)
                    model_results['Alpha'].append(a)
                    model_results['Beta'].append(b)
                    model_results['Coherence'].append(cv)
                    
                    pbar.update(1)
    pd.DataFrame(model_results).to_csv('lda_tuning_results.csv', index=False)
    pbar.close()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 390/390 [83:44:44<00:00, 773.04s/it]

# %%
pd.DataFrame(model_results).sort_values(by = ['Coherence','Topics'],ascending=False)
# Out:
#     Validation_Set  Topics       Alpha       Beta  Coherence
# 118    100% Corpus       5  asymmetric       0.91   0.460634
# 173    100% Corpus       7   symmetric       0.91   0.454982
# 178    100% Corpus       7  asymmetric       0.91   0.451349
# 352    100% Corpus      13   symmetric       0.61   0.451092
# 23     100% Corpus       2   symmetric       0.91   0.445184
# ..             ...     ...         ...        ...        ...
# 95     100% Corpus       5        0.31       0.01   0.354034
# 68     100% Corpus       4        0.31       0.91   0.352335
# 159    100% Corpus       7        0.31  symmetric   0.350764
# 365    100% Corpus      14        0.31       0.01   0.349799
# 305    100% Corpus      12        0.31       0.01   0.348803
#
# [390 rows x 5 columns]

# %%
final_lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=7, 
                                           random_state=100,
                                           chunksize=100,
                                           workers = 10,
                                           passes=10,
                                           alpha='symmetric',
                                           eta=0.91,
                                           per_word_topics=True)

# %%
# Select the model and print the topics
optimal_model = final_lda_model
model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=20))
# Out:
# [(0,
#   '0.100*"job" + 0.058*"part" + 0.027*"benefit" + 0.023*"salary" + '
#   '0.022*"enjoyable" + 0.021*"pay" + 0.021*"hardest" + 0.016*"security" + '
#   '0.015*"le" + 0.009*"compensation" + 0.008*"term" + 0.008*"low" + '
#   '0.008*"company" + 0.007*"hike" + 0.007*"time" + 0.006*"average" + '
#   '0.006*"high" + 0.006*"decent" + 0.005*"long" + 0.005*"level"'),
#  (1,
#   '0.016*"support" + 0.016*"skill" + 0.014*"client" + 0.013*"system" + '
#   '0.010*"software" + 0.010*"technical" + 0.010*"development" + '
#   '0.010*"project" + 0.009*"customer" + 0.009*"application" + 0.009*"issue" + '
#   '0.008*"service" + 0.008*"knowledge" + 0.008*"business" + 0.007*"learned" + '
#   '0.006*"process" + 0.006*"product" + 0.006*"working" + 0.005*"worked" + '
#   '0.005*"experience"'),
#  (2,
#   '0.057*"lot" + 0.045*"opportunity" + 0.043*"learn" + 0.037*"technology" + '
#   '0.031*"many" + 0.030*"thing" + 0.025*"project" + 0.020*"learned" + '
#   '0.018*"company" + 0.016*"learning" + 0.015*"different" + 0.014*"got" + '
#   '0.013*"growth" + 0.013*"training" + 0.013*"get" + 0.012*"grow" + '
#   '0.008*"learnt" + 0.007*"chance" + 0.007*"senior" + 0.007*"move"'),
#  (3,
#   '0.039*"company" + 0.034*"year" + 0.026*"worker" + 0.025*"co" + '
#   '0.025*"worked" + 0.013*"care" + 0.013*"would" + 0.012*"working" + '
#   '0.010*"one" + 0.010*"2" + 0.009*"3" + 0.009*"month" + 0.009*"health" + '
#   '0.008*"5" + 0.007*"recommend" + 0.007*"contract" + 0.007*"1" + '
#   '0.006*"started" + 0.006*"time" + 0.006*"week"'),
#  (4,
#   '0.162*"good" + 0.107*"work" + 0.040*"culture" + 0.039*"life" + '
#   '0.037*"management" + 0.035*"environment" + 0.030*"balance" + '
#   '0.027*"company" + 0.022*"place" + 0.019*"friendly" + 0.016*"employee" + '
#   '0.012*"excellent" + 0.010*"workplace" + 0.010*"supportive" + '
#   '0.009*"helpful" + 0.009*"professional" + 0.009*"working" + 0.008*"people" + '
#   '0.008*"fun" + 0.007*"benefit"'),
#  (5,
#   '0.026*"management" + 0.016*"employee" + 0.016*"time" + 0.014*"manager" + '
#   '0.011*"get" + 0.011*"people" + 0.010*"need" + 0.010*"make" + 0.009*"always" '
#   '+ 0.007*"help" + 0.007*"like" + 0.006*"would" + 0.006*"go" + 0.006*"one" + '
#   '0.005*"much" + 0.005*"way" + 0.005*"take" + 0.005*"could" + 0.005*"project" '
#   '+ 0.005*"want"'),
#  (6,
#   '0.161*"work" + 0.090*"great" + 0.049*"place" + 0.041*"working" + '
#   '0.027*"nice" + 0.026*"company" + 0.023*"experience" + 0.019*"people" + '
#   '0.015*"environment" + 0.014*"overall" + 0.014*"enjoyed" + 0.013*"start" + '
#   '0.012*"hour" + 0.012*"fun" + 0.011*"fresher" + 0.011*"really" + '
#   '0.010*"challenging" + 0.010*"home" + 0.010*"time" + 0.007*"enjoy"')]

# %%
lda_display = pyLDAvis.gensim.prepare(optimal_model, corpus, id2word, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4133229174044625602474671266"></div>
# <script type="text/javascript">
#
# var ldavis_el4133229174044625602474671266_data = {"mdsDat": {"x": [0.08074771966079143, 0.16237161207801573, 0.09135703752288646, 0.06480522600070976, -0.26132803933192833, 0.1036978151819105, -0.24165137111238494], "y": [-0.2447721671575427, 0.19254464355553874, 0.09873564930093226, -0.09390726629194886, 0.05163867642727679, -0.0056851450655808, 0.0014456092313246396], "topics": [1, 2, 3, 4, 5, 6, 7], "cluster": [1, 1, 1, 1, 1, 1, 1], "Freq": [9.311453819274902, 18.179513931274414, 12.787677764892578, 11.269526481628418, 15.579340934753418, 20.85315704345703, 12.019326210021973]}, "tinfo": {"Term": ["work", "good", "great", "job", "lot", "place", "part", "opportunity", "culture", "life", "learn", "management", "environment", "technology", "balance", "year", "company", "many", "thing", "working", "nice", "benefit", "worker", "co", "worked", "project", "friendly", "learned", "salary", "experience", "job", "part", "salary", "enjoyable", "hardest", "pay", "le", "security", "hike", "low", "term", "average", "compensation", "decent", "paid", "promotion", "bonus", "stressful", "amount", "compared", "weekend", "expectation", "perk", "overtime", "appraisal", "increase", "increment", "vacation", "education", "recognition", "certain", "rewarding", "might", "benefit", "market", "package", "high", "standard", "offer", "competitive", "long", "level", "time", "company", "get", "little", "support", "system", "application", "software", "development", "technical", "user", "using", "product", "client", "network", "server", "testing", "requirement", "code", "database", "developer", "web", "tool", "production", "solution", "design", "engineer", "computer", "involved", "test", "java", "sql", "developed", "related", "skill", "knowledge", "financial", "service", "customer", "business", "issue", "process", "project", "learned", "worked", "experience", "working", "typical", "management", "lot", "opportunity", "learn", "thing", "many", "grow", "got", "chance", "depends", "onsite", "available", "room", "explore", "politics", "scope", "gave", "loved", "move", "plenty", "technically", "alot", "professionally", "curve", "senior", "latest", "ample", "liked", "stuff", "gym", "ok", "technology", "exposure", "different", "growth", "learnt", "learned", "learning", "project", "training", "advancement", "get", "company", "organization", "give", "much", "also", "people", "year", "worker", "co", "2", "3", "month", "5", "care", "recommend", "1", "4", "health", "started", "6", "week", "ever", "contract", "india", "last", "two", "anyone", "10", "7", "8", "laid", "9", "insurance", "almost", "past", "join", "number", "campus", "worked", "would", "company", "one", "working", "day", "hour", "time", "every", "employee", "position", "good", "life", "culture", "balance", "friendly", "excellent", "workplace", "supportive", "helpful", "productive", "atmosphere", "awesome", "facility", "timing", "balanced", "healthy", "cooperative", "pro", "cool", "encouraging", "cultural", "nature", "collaborative", "pleasant", "talented", "okay", "perfect", "encourages", "cab", "approachable", "professional", "colleague", "environment", "coworkers", "work", "activity", "management", "personal", "place", "employee", "company", "fun", "also", "benefit", "manager", "people", "working", "flexible", "experience", "well", "make", "go", "keep", "say", "everything", "goal", "sure", "put", "find", "making", "decision", "look", "nothing", "upper", "anything", "often", "without", "done", "direction", "could", "trying", "let", "supervisor", "else", "deadline", "busy", "together", "constant", "constantly", "talk", "seems", "employer", "need", "never", "know", "way", "idea", "everyone", "needed", "come", "manager", "take", "always", "even", "made", "time", "management", "employee", "want", "get", "help", "people", "better", "would", "like", "much", "one", "hard", "project", "every", "great", "nice", "enjoyed", "overall", "start", "fresher", "home", "challenging", "enjoy", "love", "fast", "pressure", "wonde ...

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=reviews):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=final_lda_model, corpus=corpus, texts=reviews)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()

df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

#df_dominant_topic["Review"] = reviews_["review"] 
df_dominant_topic.head(10)
