# %% [markdown]
# # Data Preperation
#
# 1. [Read all the files](#Read-all-the-files)
# 2. [Concat into a single pandas object](#Concat-into-a-single-pandas-object)
#     * Remove duplicates
#     * Drop NAs for job title
# 3. [Clean Job Titles](#Clean-Job-Titles)
# 4. [Save as a pickle](#Save-as-a-pickle)
# 5. [Example how to use pickle](#Example-how-to-use-pickle)

# %% [markdown]
# ## Read all the files

# %%
import os

reviews_path = "../data/Database/"

files = [ reviews_path + i for i in os.listdir(reviews_path) if i.endswith("csv")]
display(files)
# Out:
# ['../data/Database/accounting.csv',
#  '../data/Database/automotive.csv',
#  '../data/Database/computer_software.csv',
#  '../data/Database/construction.csv',
#  '../data/Database/education_management.csv',
#  '../data/Database/financial.csv',
#  '../data/Database/higher_ed.csv',
#  '../data/Database/hospital_care.csv',
#  '../data/Database/IT_services.csv',
#  '../data/Database/retail.csv']

# %% [markdown]
# ## Concat into a single pandas object

# %%
import pandas as pd

li = []

#Loading in first 2 files
for f in files:
    data = pd.read_csv(f)
    data["industry"] = f.split("/")[3][:-4]
    li.append(data)
    
reviews = pd.concat(li, axis=0, ignore_index=True)

print("Total Records", reviews.shape)
# Out:
# Total Records (2587686, 14)

# %% [markdown]
# Remove unwanted rows

# %%
reviews_ = reviews.copy()
reviews_ = reviews_.drop(columns=["Unnamed: 0"])

reviews_ = reviews_.drop_duplicates()

indices = reviews_.loc[reviews_.job_title.isna(),:].index
reviews_ = reviews_.drop(indices, axis=0)

reviews = reviews_
reviews_ = None #clear it

print("Job Titles NAs",reviews["job_title"].isna().sum())
print("Total Records", reviews.shape)
display( reviews.head() )
# Out:
# Job Titles NAs 0
# Total Records (2350002, 13)
#   company_name                    review_title                   job_title  \
# 0           EY         Wonderful place to work  Senior Executive Assistant
# 1           EY                    People First     Senior Business Analyst
# 2           EY  I Enjoyed My Short Stay At EY!             Program Analyst
# 3           EY  Fun workplace, supportive team                  Consultant
# 4           EY       Great company to work for         Executive Assistant
#
#    employee_status                      location        date  \
# 0  Former Employee                   Houston, TX  2020-03-19
# 1  Former Employee                  New York, NY  2020-04-04
# 2  Former Employee                Alpharetta, GA  2020-04-04
# 3  Former Employee              Gurgaon, Haryana  2020-04-03
# 4  Former Employee  Canary Wharf, Greater London  2020-04-01
#
#                                               review  \
# 0  This company goes above and beyond to provide ...
# 1  A place where you definitely will learn about ...
# 2  This company wasn't perfect, but it's about as...
# 3  I have been appointed for busy season so we ha...
# 4  I wish I never resigned from EY - my massive m...
#
#                                                 pros        cons  rating  \
# 0                                                NaN         NaN     4.0
# 1                                                NaN         NaN     5.0
# 2  I love Work Life Balance! Also, they treat you...    Politics     4.0
# 3  Cab facilities, Flexibility for WFH, Supportiv...  team unity     4.0
# 4                                                NaN         NaN     5.0
#
#    yes_helpful  no_helpful    industry
# 0            0           0  accounting
# 1            0           0  accounting
# 2            0           0  accounting
# 3            0           0  accounting
# 4            0           0  accounting

# %% [markdown]
# ## Clean Job Titles

# %%
import string
import re

replacement_words = {
    "it":"technology"
    ,"sr":"senior"
    ,"qa":"quality"
    ,"sr": "senior"
    ,"jr": "junior"
}

translator = str.maketrans(string.punctuation, ' '*len(string.punctuation)) #map punctuation to space
def cleanTitle(title):
    title = str(title).translate(translator)
    title = re.sub(' +', ' ',title)
    title = title.lower()
    title_split = title.split(" ")
    for key, value in replacement_words.items():
        title_split = [ value if key == word else word for word in title_split ]
    return " ".join(title_split)

reviews["clean_job_title"] = reviews.job_title.apply(cleanTitle)


display( reviews[["job_title","clean_job_title"]].head() )
# Out:
#                     job_title             clean_job_title
# 0  Senior Executive Assistant  senior executive assistant
# 1     Senior Business Analyst     senior business analyst
# 2             Program Analyst             program analyst
# 3                  Consultant                  consultant
# 4         Executive Assistant         executive assistant

# %% [markdown]
# ## Save as a pickle

# %%
import pickle
import pathlib as Path

with open("../data/all_reviews.pkl","wb") as f:
    pickle.dump(reviews,f)

# %% [markdown]
# ## Example how to use pickle

# %%
import pandas as pd
import pickle

with open("../data/all_reviews.pkl","rb") as f:
    reviews = pickle.load(f)
    
display(reviews.head())
# Out:
#   company_name                    review_title                   job_title  \
# 0           EY         Wonderful place to work  Senior Executive Assistant
# 1           EY                    People First     Senior Business Analyst
# 2           EY  I Enjoyed My Short Stay At EY!             Program Analyst
# 3           EY  Fun workplace, supportive team                  Consultant
# 4           EY       Great company to work for         Executive Assistant
#
#    employee_status                      location        date  \
# 0  Former Employee                   Houston, TX  2020-03-19
# 1  Former Employee                  New York, NY  2020-04-04
# 2  Former Employee                Alpharetta, GA  2020-04-04
# 3  Former Employee              Gurgaon, Haryana  2020-04-03
# 4  Former Employee  Canary Wharf, Greater London  2020-04-01
#
#                                               review  \
# 0  This company goes above and beyond to provide ...
# 1  A place where you definitely will learn about ...
# 2  This company wasn't perfect, but it's about as...
# 3  I have been appointed for busy season so we ha...
# 4  I wish I never resigned from EY - my massive m...
#
#                                                 pros        cons  rating  \
# 0                                                NaN         NaN     4.0
# 1                                                NaN         NaN     5.0
# 2  I love Work Life Balance! Also, they treat you...    Politics     4.0
# 3  Cab facilities, Flexibility for WFH, Supportiv...  team unity     4.0
# 4                                                NaN         NaN     5.0
#
#    yes_helpful  no_helpful    industry             clean_job_title
# 0            0           0  accounting  senior executive assistant
# 1            0           0  accounting     senior business analyst
# 2            0           0  accounting             program analyst
# 3            0           0  accounting                  consultant
# 4            0           0  accounting         executive assistant
